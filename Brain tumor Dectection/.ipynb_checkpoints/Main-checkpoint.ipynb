# %%
import numpy as np
from matplotlib import pyplot as plt
import copy
import os
from torch.utils.data import Dataset
import cv2
from PIL import Image as img
from IPython.display import Image, display

# %%
image_dir = "./brain-tumor/train/images"
print(os.path.abspath(image_dir))
# Out:
# D:\ML Projects\Machine-Learning-Projects\Brain tumor Dectection\brain-tumor\train\images

# %%
label_dir = "./brain-tumor/train/labels"
print(os.path.abspath(label_dir))
# Out:
# D:\ML Projects\Machine-Learning-Projects\Brain tumor Dectection\brain-tumor\train\labels

# %%
images, labels = [], []
image_files = sorted(os.listdir(image_dir))

# %%
label_files = sorted(os.listdir(label_dir))

# %%
image = cv2.imread("./brain-tumor/train/images/62 (5).jpg")

# %%
plt.imshow(image)

# %%
# Get dimensions using Pillow
width, height = image.size
print(f"Width: {width}, Height: {height}")
# Out:
# Width: 512, Height: 512

# %%
image_array = np.array(image)
print(f"Shape: {image_array.shape}")
# Out:
# Shape: (512, 512)

# %%
image = img.open("./download.jpg")

# %%
plt.imshow(image)

# %%
image_ary = np.array(image)

# %%
gray = cv2.cvtColor (image_ary, cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (720, 1280)

# %%
plt.imshow(gray)

plt.show()

# %%
gray.shape
# Out:
# (720, 1280)

# %%
image = cv2.imread("./download.jpg")

# %%
resized = cv2.resize(image, (224,224))

# %%
plt.imshow( resized)

# %%
height, width = img.shape[2]
size = min (height, width)
x = (width - size) / 2
y = (height - size) / 2
cropped = ingly: y+size, xix+size
# Out:
#   Cell In[213], line 5
#     cropped = ingly: y+size, xix+size
#                    ^
# SyntaxError: invalid syntax
